# %% [markdown]
# <div id="top">
# <!-- <div style="background-image: url(https://www.emtmadrid.es/getattachment/da3be644-cb9d-44db-8011-e3f40f1c5c34); opacity: 0.2"/> -->
# <img src="https://www.gmv.com/sites/default/files/content/image/2021/11/03/115/gmv_rgbredblack.png" alt="GMV Logo" style="width: 200px">
# <img src="https://www.upm.es/sfs/Rectorado/Gabinete%20del%20Rector/Logos/UPM/CEI/LOGOTIPO%20leyenda%20color%20JPG%20p.png" alt="UPM Logo" style="float: right; width: 200px">
# <h1><b>EDA: AEMET dataset 🌥️</b></h1>
# <h5 style="text-align: right">INESDATA-MOV</h5>
# </div>
#
# # Análisis EDA:COMPLETAR

# %%
import requests

url_madrid = (
    "https://opendata.aemet.es/opendata/api/prediccion/especifica/municipio/horaria/28079"
)

headers = {
    "api_key": "eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJwYXRyaWNpYS5oZXJuYW5kby5zYW5jaGV6QGdtdi5jb20iLCJqdGkiOiIyMjU1YjM3MC0zZDVkLTQ3YWUtODY3Mi1lZmI0YTRhNWJlMzAiLCJpc3MiOiJBRU1FVCIsImlhdCI6MTcxMjczNTA0MSwidXNlcklkIjoiMjI1NWIzNzAtM2Q1ZC00N2FlLTg2NzItZWZiNGE0YTViZTMwIiwicm9sZSI6IiJ9.oG4Gc12WjFVRhGuh0oQWkOP6iOsXp8xKKeLd-LhtDJA",
    "Content-Type": "application/json",
    "Accept": "application/json",
}

r = requests.get(url_madrid, headers=headers)
r_json = requests.get(r.json()["datos"]).json()

# %%
r_json
# Out:
# [{'origen': {'productor': 'Agencia Estatal de Meteorología - AEMET. Gobierno de España',
#    'web': 'https://www.aemet.es',
#    'enlace': 'https://www.aemet.es/es/eltiempo/prediccion/municipios/horas/madrid-id28079',
#    'language': 'es',
#    'copyright': '© AEMET. Autorizado el uso de la información y su reproducción citando a AEMET como autora de la misma.',
#    'notaLegal': 'https://www.aemet.es/es/nota_legal'},
#   'elaborado': '2024-04-12T09:00:13',
#   'nombre': 'Madrid',
#   'provincia': 'Madrid',
#   'prediccion': {'dia': [{'estadoCielo': [{'value': '11',
#        'periodo': '08',
#        'descripcion': 'Despejado'},
#       {'value': '11', 'periodo': '09', 'descripcion': 'Despejado'},
#       {'value': '11', 'periodo': '10', 'descripcion': 'Despejado'},
#       {'value': '11', 'periodo': '11', 'descripcion': 'Despejado'},
#       {'value': '11', 'periodo': '12', 'descripcion': 'Despejado'},
#       {'value': '11', 'periodo': '13', 'descripcion': 'Despejado'},
# ...

# %%
# %cd ..
# Out:
# /home/pphs/data-generation/docs/notebooks
# /home/pphs/data-generation/venv/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
import os
import pandas as pd

# %% [markdown]
# ## Lectura de todos los datos disponibles de AEMET y unión en un DataFrame

# %%
ROOT_PATH = os.path.dirname(os.path.dirname(os.path.abspath(os.getcwd())))
DATA_PATH = os.path.join(ROOT_PATH, "data", "processed")
AEMET_DATA_PATH = os.path.join(DATA_PATH, "aemet")
AEMET_DATA_PATH
# Out:
# '/home/pphs/data-generation/data/processed/aemet'

# %%
#####################################################
# Obtain a dataframe with all the AEMET information #
#####################################################

# Set the directory containing CSV files
directory = AEMET_DATA_PATH

# Initialize an empty list to store DataFrames
aemet_data = []

# Walk through all directories and subdirectories
for root, directories, files in os.walk(directory):
    for filename in files:
        if filename.endswith('.csv'):
            # Read each CSV file into a DataFrame and append to the list
            filepath = os.path.join(root, filename)
            aemet_data.append(pd.read_csv(filepath))

# Concatenate all DataFrames in the list into a single DataFrame
aemet_dataset = pd.concat(aemet_data, ignore_index=True)

# %%
aemet_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2848 entries, 0 to 2847
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   estadoCielo_value        2624 non-null   object
#  1   estadoCielo_descripcion  2624 non-null   object
#  2   precipitacion_value      2624 non-null   object
#  3   probPrecipitacion_value  224 non-null    float64
#  4   probTormenta_value       224 non-null    float64
#  5   nieve_value              2624 non-null   object
#  6   probNieve_value          224 non-null    float64
#  7   temperatura_value        2604 non-null   float64
#  8   sensTermica_value        2604 non-null   float64
#  9   humedadRelativa_value    2604 non-null   float64
#  10  direccion                1302 non-null   object
#  11  velocidad                1302 non-null   object
#  12  vientoAndRachaMax_value  1302 non-null   float64
#  13  datetime                 2848 non-null   object
# ...

# %%
# QA

# %%
aemet_dataset["precipitacion_value"].unique()
# Out:
# array(['0', nan, '0.1', '0.6', '6', '0.2', '1', '0.5', '4', '0.9', '0.8',
#        '0.7', 'Ip', '0.3', '3', '2', '0.4', 0.0, 0.1, 0.6, 6.0, 0.2, 1.0,
#        0.5, 4.0, 0.9, 3.0, 2.0, 0.4, 0.3, 0.7, 0.8], dtype=object)

# %%
# El código Ip significa precipitación inapreciable, es decir, cantidad inferior a 0.1 mm.-> Lo ponemos como 0.

# %%
aemet_dataset[aemet_dataset["precipitacion_value"]=="Ip"].head()
# Out:
#      estadoCielo_value estadoCielo_descripcion precipitacion_value  \
# 897                16n                Cubierto                  Ip
# 898                16n                Cubierto                  Ip
# 1191               16n                Cubierto                  Ip
# 1192               16n                Cubierto                  Ip
# 1415                13      Intervalos nubosos                  Ip
#
#       probPrecipitacion_value  probTormenta_value nieve_value  \
# 897                       NaN                 NaN           0
# 898                       NaN                 NaN           0
# 1191                      NaN                 NaN           0
# 1192                      NaN                 NaN           0
# 1415                      NaN                 NaN           0
#
#       probNieve_value  temperatura_value  sensTermica_value  \
# 897               NaN               13.0               13.0
# 898               NaN               13.0               13.0
# ...

# %%
aemet_dataset = aemet_dataset.replace({'precipitacion_value': {"Ip":0.0}, 'nieve_value': {"Ip":0.0}})
aemet_dataset[aemet_dataset["precipitacion_value"]=="Ip"].head()
# Out:
# Empty DataFrame
# Columns: [estadoCielo_value, estadoCielo_descripcion, precipitacion_value, probPrecipitacion_value, probTormenta_value, nieve_value, probNieve_value, temperatura_value, sensTermica_value, humedadRelativa_value, direccion, velocidad, vientoAndRachaMax_value, datetime]
# Index: []

# %%
aemet_dataset = aemet_dataset.astype({'estadoCielo_value': 'str', 'estadoCielo_descripcion':'str',\
                      'precipitacion_value': 'float64', 'probPrecipitacion_value': 'float64',\
                      'probTormenta_value': 'float64', 'nieve_value': 'float64',\
                      'probNieve_value': 'float64', 'temperatura_value': 'float64',\
                      'sensTermica_value': 'float64', 'humedadRelativa_value': 'float64',\
                      'vientoAndRachaMax_value': 'float64'                    
                      })

# %%
aemet_dataset.head()
# Out:
#   estadoCielo_value estadoCielo_descripcion  precipitacion_value  \
# 0               12n             Poco nuboso                  0.0
# 1               12n             Poco nuboso                  0.0
# 2               15n              Muy nuboso                  0.0
# 3               15n              Muy nuboso                  0.0
# 4               nan                     nan                  NaN
#
#    probPrecipitacion_value  probTormenta_value  nieve_value  probNieve_value  \
# 0                      NaN                 NaN          0.0              NaN
# 1                      NaN                 NaN          0.0              NaN
# 2                      NaN                 NaN          0.0              NaN
# 3                      NaN                 NaN          0.0              NaN
# 4                      0.0                 0.0          NaN              0.0
#
#    temperatura_value  sensTermica_value  humedadRelativa_value direccion  \
# ...

# %%
aemet_dataset.drop_duplicates()[aemet_dataset["datetime"]=="2024-03-02 00:00:00"]
# Out:
# /tmp/ipykernel_11062/1249086161.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   aemet_dataset.drop_duplicates()[aemet_dataset["datetime"]=="2024-03-02 00:00:00"]
#   estadoCielo_value estadoCielo_descripcion  precipitacion_value  \
# 0               12n             Poco nuboso                  0.0
# 1               12n             Poco nuboso                  0.0
#
#    probPrecipitacion_value  probTormenta_value  nieve_value  probNieve_value  \
# 0                      NaN                 NaN          0.0              NaN
# 1                      NaN                 NaN          0.0              NaN
#
#    temperatura_value  sensTermica_value  humedadRelativa_value direccion  \
# 0                8.0                5.0                   77.0    ['SO']
# 1                8.0                5.0                   77.0       NaN
#
#   velocidad  vientoAndRachaMax_value             datetime
# 0    ['16']                      NaN  2024-03-02 00:00:00
# ...

# %%
aemet_dataset = aemet_dataset.drop_duplicates()

# %%
import pandas as pd

# Group by columns 'A' and 'B' and merge values in column 'C'
aemet_reduced = aemet_dataset.groupby(["datetime"])[['direccion','velocidad','vientoAndRachaMax_value']].sum()

# merged_df["datetime"] = pd.to_datetime(merged_df["datetime"])
# merged_df

# %%
aemet_dataset = aemet_dataset.drop(columns=["direccion", "velocidad", "vientoAndRachaMax_value"])

# %%
aemet_dataset.head(2)
# Out:
#   estadoCielo_value estadoCielo_descripcion  precipitacion_value  \
# 0               12n             Poco nuboso                  0.0
# 2               15n              Muy nuboso                  0.0
#
#    probPrecipitacion_value  probTormenta_value  nieve_value  probNieve_value  \
# 0                      NaN                 NaN          0.0              NaN
# 2                      NaN                 NaN          0.0              NaN
#
#    temperatura_value  sensTermica_value  humedadRelativa_value  \
# 0                8.0                5.0                   77.0
# 2                8.0                5.0                   80.0
#
#               datetime
# 0  2024-03-02 00:00:00
# 2  2024-03-02 01:00:00

# %%
a = aemet_dataset.merge(aemet_reduced, how="inner", on= "datetime")

# %%
a["datetime"] = pd.to_datetime(a["datetime"])

# %%
a["day"] = a["datetime"].dt.day
a["month"] = a["datetime"].dt.month
a["year"] = a["datetime"].dt.year
a["hour"] = a["datetime"].dt.hour
a["minute"] = a["datetime"].dt.minute

# %%
a[a["minute"]==0].groupby(["month", "day"])[["estadoCielo_value"]].count()
# Out:
#            estadoCielo_value
# month day
# 3     2                   24
#       3                   24
#       4                   24
#       5                   24
#       6                   24
#       7                   24
#       8                   24
#       11                  24
#       12                  24
#       13                  24
#       14                  24
#       15                  24
#       16                  24
#       17                  24
#       18                  24
#       19                  24
#       20                  24
#       21                  24
#       22                  23
#       23                  23
#       24                  23
#       25                  23
#       26                  23
#       27                  23
#       28                  23
#       29                  23
#       30                  23
#       31                  22

# %% [markdown]
# ## Análisis del dataset

# %%
# ¿Qué hay que analizar?
# * Variables a missing
# * Variables constantes
# * Outliers

# %%
# Dataset information
aemet_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2848 entries, 0 to 2847
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   estadoCielo_value        2624 non-null   object
#  1   estadoCielo_descripcion  2624 non-null   object
#  2   precipitacion_value      2624 non-null   object
#  3   probPrecipitacion_value  224 non-null    float64
#  4   probTormenta_value       224 non-null    float64
#  5   nieve_value              2624 non-null   object
#  6   probNieve_value          224 non-null    float64
#  7   temperatura_value        2604 non-null   float64
#  8   sensTermica_value        2604 non-null   float64
#  9   humedadRelativa_value    2604 non-null   float64
#  10  direccion                1302 non-null   object
#  11  velocidad                1302 non-null   object
#  12  vientoAndRachaMax_value  1302 non-null   float64
#  13  datetime                 2848 non-null   object
# ...

# %% [markdown]
# ## QA checks ✅

# %% [markdown]
# ## Pasos previos: Fecha y hora en columnas distintas
#
# Para realizar el análisis de la forma más sencilla posible se separará la columna *datetime* en dos columnas distintas: *date* and *time*

# %%
# Convert the datetime column to pandas datetime format
aemet_dataset['datetime'] = pd.to_datetime(aemet_dataset['datetime'])

# Split the datetime column into separate date and time columns
aemet_dataset['date'] = aemet_dataset['datetime'].dt.date
aemet_dataset['time'] = aemet_dataset['datetime'].dt.time

# Drop the original datetime column if no longer needed
aemet_dataset.drop(columns=['datetime'], inplace=True)

# %%
aemet_dataset[["date", "time"]].head(10)
# Out:
#          date      time
# 0  2024-03-02  00:00:00
# 1  2024-03-02  00:00:00
# 2  2024-03-02  01:00:00
# 3  2024-03-02  01:00:00
# 4  2024-03-02  01:07:00
# 5  2024-03-02  02:00:00
# 6  2024-03-02  02:00:00
# 7  2024-03-02  03:00:00
# 8  2024-03-02  03:00:00
# 9  2024-03-02  04:00:00

# %%
# Hay fechas duplicadas (mismo día y hora) -> 
# Mirar en la API si ocurre siempre o es un error de carga

# %% [markdown]
# ### Unicidad
#
# Cada fila del dataset representa la situación climatológica para

# %%
# Variables:
# * estadoCielo_value == estadoCielo_descripcion -> ver si son iguales y dejar solo una
# * precipitation_value <-> probPrecipitation_value <-> probTormenta_value -> Mirar correlación
# * nieve_value <-> probNieve_value -> Mirar correlación
# * temperatura_value <-> sensTermica_value -> Mirar correlación
# * datetime -> separar en día y horas

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   estadoCielo_value        48 non-null     object
#  1   estadoCielo_descripcion  48 non-null     object
#  2   precipitacion_value      48 non-null     float64
#  3   probPrecipitacion_value  4 non-null      float64
#  4   probTormenta_value       4 non-null      float64
#  5   nieve_value              48 non-null     float64
#  6   probNieve_value          4 non-null      float64
#  7   temperatura_value        48 non-null     float64
#  8   sensTermica_value        48 non-null     float64
#  9   humedadRelativa_value    48 non-null     float64
#  10  direccion                24 non-null     object
#  11  velocidad                24 non-null     object
#  12  vientoAndRachaMax_value  24 non-null     float64
# ...

# %%
df[["estadoCielo_value", "estadoCielo_descripcion"]].groupby(["estadoCielo_value", "estadoCielo_descripcion"]).count()
# Out:
# Empty DataFrame
# Columns: []
# Index: [(11, Despejado), (11n, Despejado), (12, Poco nuboso), (12n, Poco nuboso), (17, Nubes altas), (17n, Nubes altas)]

# %%
df[df["probPrecipitacion_value"].notnull()]
# Out:
#    estadoCielo_value estadoCielo_descripcion  precipitacion_value  \
# 4                NaN                     NaN                  NaN
# 17               NaN                     NaN                  NaN
# 30               NaN                     NaN                  NaN
# 43               NaN                     NaN                  NaN
#
#     probPrecipitacion_value  probTormenta_value  nieve_value  probNieve_value  \
# 4                       0.0                 0.0          NaN              0.0
# 17                      0.0                 0.0          NaN              0.0
# 30                      0.0                 0.0          NaN              0.0
# 43                      0.0                 0.0          NaN              0.0
#
#     temperatura_value  sensTermica_value  humedadRelativa_value direccion  \
# 4                 NaN                NaN                    NaN       NaN
# 17                NaN                NaN                    NaN       NaN
# ...
